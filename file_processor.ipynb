# %% [markdown]
# # Libraries

# %%
import pandas as pd
import json
from enum import Enum
import datetime

# %% [markdown]
# # Common functions

# %% [markdown]
# ## Cast functions

# %%
def cast_col_to_datetime(df: pd.DataFrame, column_name: str) -> pd.DataFrame:
    df[column_name] = pd.to_datetime(df[column_name], format='ISO8601')
    return df

def cast_col_to_str(df: pd.DataFrame, column_name: str) -> pd.DataFrame:
    df[column_name] = df[column_name].astype(str)
    return df

def cast_col_to_int(df: pd.DataFrame, column_name: str) -> pd.DataFrame:
    df[column_name] = df[column_name].astype(int)
    return df

def cast_col_to_date(df: pd.DataFrame, column_name: str) -> pd.DataFrame:
    df[column_name] = pd.to_datetime(df[column_name], format='%d.%m.%Y')
    return df

class ColCast(Enum):
    TO_DATETIME = cast_col_to_datetime
    TO_DATE = cast_col_to_date
    TO_STRING = cast_col_to_str
    TO_INTEGER = cast_col_to_int

def cast_columns(df: pd.DataFrame, cast_mapping: dict[str:ColCast]) -> pd.DataFrame:
    # perform check if provided mapping matches dataframe
    columns_match = set(df.columns) == set(cast_mapping.keys())
    if not columns_match:
        raise Exception("Provided mapping do not match the columns of the dataframe.")
    
    for col_name, cast_func in cast_mapping.items():
        df = cast_func(df, col_name)

    return df

# %% [markdown]
# # Extract

# %% [markdown]
# ## Read data.csv

# %%
applications_df = pd.read_csv("./data.csv")

# %% [markdown]
# # Transform

# %% [markdown]
# ## Apply datatype casting on dataframe columns

# %%
applications_datatypes = {
    "id": ColCast.TO_INTEGER,
    "application_date": ColCast.TO_DATETIME,
    "contracts": ColCast.TO_STRING, 
}

# %%
casted_df = cast_columns(applications_df.copy(), applications_datatypes)

# %% [markdown]
# ## Parse contracts column

# %%
casted_df['contracts'] = casted_df['contracts'].replace('nan', '[{}]')
casted_df['contracts'] = casted_df['contracts'].apply(json.loads)
exploded_df = casted_df.explode('contracts').reset_index(drop=True)

# %%
flattened_df = pd.json_normalize(exploded_df['contracts'])
parsed_df = pd.concat([exploded_df, flattened_df], axis=1)

# %% [markdown]
# ## Calculate tot_claim_cnt_l180d feature

# %%
current_date = pd.Timestamp(datetime.datetime.now())
minus_180_days = current_date - pd.Timedelta(days=180)

# %%
claim_df = parsed_df.copy()
claim_df['claim_date'] = pd.to_datetime(parsed_df['claim_date'])
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6904\72844443.py:2: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   claim_df['claim_date'] = pd.to_datetime(parsed_df['claim_date'])

# %%
claim_df = claim_df[(claim_df['claim_date'].notnull()) & (claim_df['claim_date'] > minus_180_days)]
cnt_l180d_feature_df = claim_df.groupby('id')['claim_id'].count().reset_index(name='tot_claim_cnt_l180d')

# %%
parsed_df = parsed_df.merge(cnt_l180d_feature_df, on='id', how='left')
parsed_df['tot_claim_cnt_l180d'].fillna(-3, inplace=True)
parsed_df['tot_claim_cnt_l180d'] = parsed_df['tot_claim_cnt_l180d'].astype(int)

# %%
parsed_df
# Out:
#             id                 application_date  \
# 0      2925210 2024-02-12 19:22:46.652000+00:00
# 1      2925211 2024-02-12 19:24:29.135000+00:00
# 2      2925211 2024-02-12 19:24:29.135000+00:00
# 3      2925211 2024-02-12 19:24:29.135000+00:00
# 4      2925211 2024-02-12 19:24:29.135000+00:00
# ...        ...                              ...
# 10064  2926205 2024-02-13 06:09:54.210000+00:00
# 10065  2926206 2024-02-13 06:09:54.306000+00:00
# 10066  2926207 2024-02-13 06:09:55.661000+00:00
# 10067  2926208 2024-02-13 06:09:57.024000+00:00
# 10068  2926209 2024-02-13 06:10:00.403000+00:00
#
#                                                contracts contract_id bank  \
# 0                                                     {}         NaN  NaN
# 1      {'contract_id': 522530, 'bank': '003', 'summa'...      522530  003
# 2      {'contract_id': '', 'bank': '014', 'summa': ''...              014
# 3      {'contract_id': '', 'bank': '014', 'summa': ''...              014
# 4      {'contract_id': '', 'bank': '014', 'summa': ''...              014
# ...                                                  ...         ...  ...
# 10064  {'contract_id': '', 'bank': '014', 'summa': ''...              014
# 10065                                                 {}         NaN  NaN
# 10066                                                 {}         NaN  NaN
# 10067                                                 {}         NaN  NaN
# 10068                                                 {}         NaN  NaN
#
#            summa loan_summa  claim_date   claim_id contract_date  \
# 0            NaN        NaN         NaN        NaN           NaN
# 1      500000000          0  13.02.2020     609965    17.02.2020
# 2                            28.08.2020  F00013731
# 3                            08.10.2020  F00021301
# 4                            25.11.2020  F00037907
# ...          ...        ...         ...        ...           ...
# 10064                        31.05.2023  F00895453
# 10065        NaN        NaN         NaN        NaN           NaN
# 10066        NaN        NaN         NaN        NaN           NaN
# 10067        NaN        NaN         NaN        NaN           NaN
# 10068        NaN        NaN         NaN        NaN           NaN
#
#        tot_claim_cnt_l180d
# 0                       -3
# 1                       -3
# 2                       -3
# 3                       -3
# 4                       -3
# ...                    ...
# 10064                   -3
# 10065                   -3
# 10066                   -3
# 10067                   -3
# 10068                   -3
#
# [10069 rows x 11 columns]

# %% [markdown]
# ## Calculate disb_bank_loan_wo_tbc feature

# %% [markdown]
# The task `Sum of exposue of loans without TBC loans. Exposure means here field "loan_summa".` is not clear. What does mean `without TBC loans`? Which bank is it?

# %% [markdown]
# Feature disb_bank_loan_wo_tbc will be calculated as sum of 'loan_summa' where it is not null, 'contract_date' is not null and TBC Bank will have 014 value.

# %%
loan_df = parsed_df[['id', 'bank', 'contract_date', 'loan_summa']]
loan_df = loan_df[(~loan_df['bank'].isin(['LIZ', 'LOM', 'MKO', 'SUG', '014'])) & (loan_df['bank'].notnull()) & (loan_df['contract_date'].notnull()) & (loan_df['contract_date'] != '')]
loan_df = loan_df[(loan_df['loan_summa'] != '')]
loan_df['loan_summa'] = loan_df['loan_summa'].astype('Int64')
loan_wo_tbc_feature_df = loan_df.groupby('id')['loan_summa'].sum().reset_index(name='disb_bank_loan_wo_tbc')

# %%
parsed_df = parsed_df.merge(loan_wo_tbc_feature_df, on='id', how='left')
parsed_df['disb_bank_loan_wo_tbc'].fillna(-3, inplace=True)
parsed_df.loc[parsed_df['disb_bank_loan_wo_tbc'] == 0, 'disb_bank_loan_wo_tbc'] = -1

# %%
parsed_df
# Out:
#             id                 application_date  \
# 0      2925210 2024-02-12 19:22:46.652000+00:00
# 1      2925211 2024-02-12 19:24:29.135000+00:00
# 2      2925211 2024-02-12 19:24:29.135000+00:00
# 3      2925211 2024-02-12 19:24:29.135000+00:00
# 4      2925211 2024-02-12 19:24:29.135000+00:00
# ...        ...                              ...
# 10064  2926205 2024-02-13 06:09:54.210000+00:00
# 10065  2926206 2024-02-13 06:09:54.306000+00:00
# 10066  2926207 2024-02-13 06:09:55.661000+00:00
# 10067  2926208 2024-02-13 06:09:57.024000+00:00
# 10068  2926209 2024-02-13 06:10:00.403000+00:00
#
#                                                contracts contract_id bank  \
# 0                                                     {}         NaN  NaN
# 1      {'contract_id': 522530, 'bank': '003', 'summa'...      522530  003
# 2      {'contract_id': '', 'bank': '014', 'summa': ''...              014
# 3      {'contract_id': '', 'bank': '014', 'summa': ''...              014
# 4      {'contract_id': '', 'bank': '014', 'summa': ''...              014
# ...                                                  ...         ...  ...
# 10064  {'contract_id': '', 'bank': '014', 'summa': ''...              014
# 10065                                                 {}         NaN  NaN
# 10066                                                 {}         NaN  NaN
# 10067                                                 {}         NaN  NaN
# 10068                                                 {}         NaN  NaN
#
#            summa loan_summa  claim_date   claim_id contract_date  \
# 0            NaN        NaN         NaN        NaN           NaN
# 1      500000000          0  13.02.2020     609965    17.02.2020
# 2                            28.08.2020  F00013731
# 3                            08.10.2020  F00021301
# 4                            25.11.2020  F00037907
# ...          ...        ...         ...        ...           ...
# 10064                        31.05.2023  F00895453
# 10065        NaN        NaN         NaN        NaN           NaN
# 10066        NaN        NaN         NaN        NaN           NaN
# 10067        NaN        NaN         NaN        NaN           NaN
# 10068        NaN        NaN         NaN        NaN           NaN
#
#        tot_claim_cnt_l180d  disb_bank_loan_wo_tbc
# 0                       -3                     -3
# 1                       -3                     -1
# 2                       -3                     -1
# 3                       -3                     -1
# 4                       -3                     -1
# ...                    ...                    ...
# 10064                   -3              217320883
# 10065                   -3                     -3
# 10066                   -3                     -3
# 10067                   -3                     -3
# 10068                   -3                     -3
#
# [10069 rows x 12 columns]

# %% [markdown]
# ## Calculate day_sinlastloan feature

# %%
last_loan_df = parsed_df[['id', 'summa', 'contract_date', 'application_date']]
last_loan_df['contract_date'] = pd.to_datetime(last_loan_df['contract_date'])
last_loan_df['application_date'] = pd.to_datetime(last_loan_df['application_date'])
assert last_loan_df['application_date'].dtype == last_loan_df['contract_date'].dtype
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6904\1708946114.py:2: UserWarning: Parsing dates in %d.%m.%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   last_loan_df['contract_date'] = pd.to_datetime(last_loan_df['contract_date'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6904\1708946114.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_loan_df['contract_date'] = pd.to_datetime(last_loan_df['contract_date'])
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_6904\1708946114.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_loan_df['application_date'] = pd.to_datetime(last_loan_df['application_date'])
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# c:\Users\Lenovo\Documents\Work\TBC\Assessment\tbc_python_assessment\file_processor.ipynb Cell 29 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y113sZmlsZQ%3D%3D?line=1'>2</a> last_loan_df['contract_date'] = pd.to_datetime(last_loan_df['contract_date'])
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y113sZmlsZQ%3D%3D?line=2'>3</a> last_loan_df['application_date'] = pd.to_datetime(last_loan_df['application_date'])
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y113sZmlsZQ%3D%3D?line=3'>4</a> assert last_loan_df['application_date'].dtype == last_loan_df['contract_date'].dtype
#
# AssertionError:

# %%
last_loan_df
# Out:
#             id      summa contract_date                 application_date
# 0      2925210        NaN           NaT 2024-02-12 19:22:46.652000+00:00
# 1      2925211  500000000    2020-02-17 2024-02-12 19:24:29.135000+00:00
# 2      2925211                      NaT 2024-02-12 19:24:29.135000+00:00
# 3      2925211                      NaT 2024-02-12 19:24:29.135000+00:00
# 4      2925211                      NaT 2024-02-12 19:24:29.135000+00:00
# ...        ...        ...           ...                              ...
# 10064  2926205                      NaT 2024-02-13 06:09:54.210000+00:00
# 10065  2926206        NaN           NaT 2024-02-13 06:09:54.306000+00:00
# 10066  2926207        NaN           NaT 2024-02-13 06:09:55.661000+00:00
# 10067  2926208        NaN           NaT 2024-02-13 06:09:57.024000+00:00
# 10068  2926209        NaN           NaT 2024-02-13 06:10:00.403000+00:00
#
# [10069 rows x 4 columns]

# %%
# custom grouping function
def calculate_days_since_last_loan(group: pd.DataFrame):
    group = group.sort_values('contract_date')
    group['day_sinlastloan'] = group.apply(
        lambda row: (row['application_date'] - group[group['contract_date'] <= row['application_date']]['contract_date'].max()).days, axis=1
    )
    return group

# %%
day_sinlastloan_feature_df = last_loan_df.groupby('id').apply(calculate_days_since_last_loan).reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimelike.py:565, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     564 try:
# --> 565     self._check_compatible_with(other)
#     566 except (TypeError, IncompatibleFrequency) as err:
#     567     # e.g. tzawareness mismatch
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimes.py:522, in DatetimeArray._check_compatible_with(self, other)
#     521     return
# --> 522 self._assert_tzawareness_compat(other)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimes.py:744, in DatetimeArray._assert_tzawareness_compat(self, other)
#     743     if other_tz is not None:
# --> 744         raise TypeError(
#     745             "Cannot compare tz-naive and tz-aware datetime-like objects."
#     746         )
#     747 elif other_tz is None:
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects.
#
# The above exception was the direct cause of the following exception:
#
# InvalidComparison                         Traceback (most recent call last)
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimelike.py:935, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     934 try:
# --> 935     other = self._validate_comparison_value(other)
#     936 except InvalidComparison:
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimelike.py:568, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     566     except (TypeError, IncompatibleFrequency) as err:
#     567         # e.g. tzawareness mismatch
# --> 568         raise InvalidComparison(other) from err
#     570 elif not is_list_like(other):
#
# InvalidComparison: 2024-02-12 19:22:46.652000+00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\groupby\groupby.py:1353, in GroupBy.apply(self, func, *args, **kwargs)
#    1352 try:
# -> 1353     result = self._python_apply_general(f, self._selected_obj)
#    1354 except TypeError:
#    1355     # gh-20949
#    1356     # try again, with .apply acting as a filtering
#    (...)
#    1360     # fails on *some* columns, e.g. a numeric operation
#    1361     # on a string grouper column
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\groupby\groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1376 """
#    1377 Apply function f in python space
#    1378
#    (...)
#    1400     data after applying f
#    1401 """
# -> 1402 values, mutated = self.grouper.apply(f, data, self.axis)
#    1403 if not_indexed_same is None:
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\groupby\ops.py:767, in BaseGrouper.apply(self, f, data, axis)
#     766 group_axes = group.axes
# --> 767 res = f(group)
#     768 if not mutated and not _is_indexed_like(res, group_axes, axis):
#
# c:\Users\Lenovo\Documents\Work\TBC\Assessment\tbc_python_assessment\file_processor.ipynb Cell 31 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=2'>3</a> group = group.sort_values('contract_date')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=3'>4</a> group['day_sinlastloan'] = group.apply(
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=4'>5</a>     lambda row: (row['application_date'] - group[group['contract_date'] <= row['application_date']]['contract_date'].max()).days, axis=1
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=5'>6</a> )
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=6'>7</a> return group
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     812 for i, v in enumerate(series_gen):
#     813     # ignore SettingWithCopy here in case the user mutates
# --> 814     results[i] = self.f(v)
#     815     if isinstance(results[i], ABCSeries):
#     816         # If we have a view on v, we need to make a copy because
#     817         #  series_generator will swap out the underlying data
#
# c:\Users\Lenovo\Documents\Work\TBC\Assessment\tbc_python_assessment\file_processor.ipynb Cell 31 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=2'>3</a> group = group.sort_values('contract_date')
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=3'>4</a> group['day_sinlastloan'] = group.apply(
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=4'>5</a>     lambda row: (row['application_date'] - group[group['contract_date'] <= row['application_date']]['contract_date'].max()).days, axis=1
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=5'>6</a> )
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=6'>7</a> return group
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arraylike.py:52, in OpsMixin.__le__(self, other)
#      50 @unpack_zerodim_and_defer("__le__")
#      51 def __le__(self, other):
# ---> 52     return self._cmp_method(other, operator.le)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\series.py:6096, in Series._cmp_method(self, other, op)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\ops\array_ops.py:279, in comparison_op(left, right, op)
#     274 if should_extension_dispatch(lvalues, rvalues) or (
#     275     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     276     and not is_object_dtype(lvalues.dtype)
#     277 ):
#     278     # Call the method on lvalues
# --> 279     res_values = op(lvalues, rvalues)
#     281 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     282     # numpy does not like comparisons vs None
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arraylike.py:52, in OpsMixin.__le__(self, other)
#      50 @unpack_zerodim_and_defer("__le__")
#      51 def __le__(self, other):
# ---> 52     return self._cmp_method(other, operator.le)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimelike.py:937, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     936 except InvalidComparison:
# --> 937     return invalid_comparison(self, other, op)
#     939 dtype = getattr(other, "dtype", None)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\ops\invalid.py:36, in invalid_comparison(left, right, op)
#      35     typ = type(right).__name__
# ---> 36     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      37 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and Timestamp
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimelike.py:565, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     564 try:
# --> 565     self._check_compatible_with(other)
#     566 except (TypeError, IncompatibleFrequency) as err:
#     567     # e.g. tzawareness mismatch
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimes.py:522, in DatetimeArray._check_compatible_with(self, other)
#     521     return
# --> 522 self._assert_tzawareness_compat(other)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimes.py:744, in DatetimeArray._assert_tzawareness_compat(self, other)
#     743     if other_tz is not None:
# --> 744         raise TypeError(
#     745             "Cannot compare tz-naive and tz-aware datetime-like objects."
#     746         )
#     747 elif other_tz is None:
#
# TypeError: Cannot compare tz-naive and tz-aware datetime-like objects.
#
# The above exception was the direct cause of the following exception:
#
# InvalidComparison                         Traceback (most recent call last)
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimelike.py:935, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     934 try:
# --> 935     other = self._validate_comparison_value(other)
#     936 except InvalidComparison:
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimelike.py:568, in DatetimeLikeArrayMixin._validate_comparison_value(self, other)
#     566     except (TypeError, IncompatibleFrequency) as err:
#     567         # e.g. tzawareness mismatch
# --> 568         raise InvalidComparison(other) from err
#     570 elif not is_list_like(other):
#
# InvalidComparison: 2024-02-12 19:22:46.652000+00:00
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# c:\Users\Lenovo\Documents\Work\TBC\Assessment\tbc_python_assessment\file_processor.ipynb Cell 31 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=0'>1</a> day_sinlastloan_feature_df = last_loan_df.groupby('id').apply(calculate_days_since_last_loan).reset_index(drop=True)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\groupby\groupby.py:1363, in GroupBy.apply(self, func, *args, **kwargs)
#    1353         result = self._python_apply_general(f, self._selected_obj)
#    1354     except TypeError:
#    1355         # gh-20949
#    1356         # try again, with .apply acting as a filtering
#    (...)
#    1360         # fails on *some* columns, e.g. a numeric operation
#    1361         # on a string grouper column
# -> 1363         return self._python_apply_general(f, self._obj_with_exclusions)
#    1365 return result
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\groupby\groupby.py:1402, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1367 @final
#    1368 def _python_apply_general(
#    1369     self,
#    (...)
#    1374     is_agg: bool = False,
#    1375 ) -> NDFrameT:
#    1376     """
#    1377     Apply function f in python space
#    1378
#    (...)
#    1400         data after applying f
#    1401     """
# -> 1402     values, mutated = self.grouper.apply(f, data, self.axis)
#    1403     if not_indexed_same is None:
#    1404         not_indexed_same = mutated
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\groupby\ops.py:767, in BaseGrouper.apply(self, f, data, axis)
#     765 # group might be modified
#     766 group_axes = group.axes
# --> 767 res = f(group)
#     768 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     769     mutated = True
#
# c:\Users\Lenovo\Documents\Work\TBC\Assessment\tbc_python_assessment\file_processor.ipynb Cell 31 line 4
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=1'>2</a> def calculate_days_since_last_loan(group: pd.DataFrame):
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=2'>3</a>     group = group.sort_values('contract_date')
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=3'>4</a>     group['day_sinlastloan'] = group.apply(
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=4'>5</a>         lambda row: (row['application_date'] - group[group['contract_date'] <= row['application_date']]['contract_date'].max()).days, axis=1
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=5'>6</a>     )
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=6'>7</a>     return group
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# c:\Users\Lenovo\Documents\Work\TBC\Assessment\tbc_python_assessment\file_processor.ipynb Cell 31 line 5
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=1'>2</a> def calculate_days_since_last_loan(group: pd.DataFrame):
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=2'>3</a>     group = group.sort_values('contract_date')
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=3'>4</a>     group['day_sinlastloan'] = group.apply(
# ----> <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=4'>5</a>         lambda row: (row['application_date'] - group[group['contract_date'] <= row['application_date']]['contract_date'].max()).days, axis=1
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=5'>6</a>     )
#       <a href='vscode-notebook-cell:/c%3A/Users/Lenovo/Documents/Work/TBC/Assessment/tbc_python_assessment/file_processor.ipynb#Y135sZmlsZQ%3D%3D?line=6'>7</a>     return group
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arraylike.py:52, in OpsMixin.__le__(self, other)
#      50 @unpack_zerodim_and_defer("__le__")
#      51 def __le__(self, other):
# ---> 52     return self._cmp_method(other, operator.le)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\series.py:6096, in Series._cmp_method(self, other, op)
#    6093 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    6095 with np.errstate(all="ignore"):
# -> 6096     res_values = ops.comparison_op(lvalues, rvalues, op)
#    6098 return self._construct_result(res_values, name=res_name)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\ops\array_ops.py:279, in comparison_op(left, right, op)
#     270         raise ValueError(
#     271             "Lengths must match to compare", lvalues.shape, rvalues.shape
#     272         )
#     274 if should_extension_dispatch(lvalues, rvalues) or (
#     275     (isinstance(rvalues, (Timedelta, BaseOffset, Timestamp)) or right is NaT)
#     276     and not is_object_dtype(lvalues.dtype)
#     277 ):
#     278     # Call the method on lvalues
# --> 279     res_values = op(lvalues, rvalues)
#     281 elif is_scalar(rvalues) and isna(rvalues):  # TODO: but not pd.NA?
#     282     # numpy does not like comparisons vs None
#     283     if op is operator.ne:
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\ops\common.py:81, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      77             return NotImplemented
#      79 other = item_from_zerodim(other)
# ---> 81 return method(self, other)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arraylike.py:52, in OpsMixin.__le__(self, other)
#      50 @unpack_zerodim_and_defer("__le__")
#      51 def __le__(self, other):
# ---> 52     return self._cmp_method(other, operator.le)
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\arrays\datetimelike.py:937, in DatetimeLikeArrayMixin._cmp_method(self, other, op)
#     935     other = self._validate_comparison_value(other)
#     936 except InvalidComparison:
# --> 937     return invalid_comparison(self, other, op)
#     939 dtype = getattr(other, "dtype", None)
#     940 if is_object_dtype(dtype):
#     941     # We have to use comp_method_OBJECT_ARRAY instead of numpy
#     942     #  comparison otherwise it would fail to raise when
#     943     #  comparing tz-aware and tz-naive
#
# File c:\Users\Lenovo\Tools\Anaconda3\envs\SparkPython\Lib\site-packages\pandas\core\ops\invalid.py:36, in invalid_comparison(left, right, op)
#      34 else:
#      35     typ = type(right).__name__
# ---> 36     raise TypeError(f"Invalid comparison between dtype={left.dtype} and {typ}")
#      37 return res_values
#
# TypeError: Invalid comparison between dtype=datetime64[ns] and Timestamp
